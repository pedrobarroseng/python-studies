# %% [markdown]
# <a href="https://colab.research.google.com/github/PedroBarros-bit/python-exerc-cios/blob/main/Hello%2C%20git.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
while True:
  print('hello, git!')
  break
# Out:
# hello, git!
